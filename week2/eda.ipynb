# %%
# ============================================
# F1 LAP ANALYSIS — EDA (WEEK 2)
# ============================================
# Objective:
# Explore synthetic QA test execution data to identify:
# - failure patterns
# - module instability
# - execution behavior
# - environment impact
# ============================================
